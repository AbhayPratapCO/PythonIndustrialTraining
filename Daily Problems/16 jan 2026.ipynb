# %%
age = int(input())

if age >= 18:
    print("Eligible to Vote")
else:
    print("Not Eligible")

# %%
n = int(input())
print(n % 10)

# %%
n = int(input())

if n % 2 == 0:
    print("Even")
else:
    print("Odd")
