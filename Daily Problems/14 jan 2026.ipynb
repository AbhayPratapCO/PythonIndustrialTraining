# %%
a = 10
b = 3.5
c = "Hello"

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
a = int(input())

print(6 * a * a)
print(a * a * a)
# Out:
# 3456
# 13824
